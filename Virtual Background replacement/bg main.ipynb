# %%
# %pip install mediapipe opencv-python
# %pip install numpy
# %pip install opencv-python
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: opencv-python in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (4.11.0.86)
# Collecting absl-py (from mediapipe)
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting attrs>=19.1.0 (from mediapipe)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting jax (from mediapipe)
#   Using cached jax-0.6.0-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Using cached jaxlib-0.6.0-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Collecting matplotlib (from mediapipe)
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting numpy<2 (from mediapipe)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Using cached protobuf-4.25.7-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.5.2-py3-none-win_amd64.whl.metadata (1.6 kB)
# Collecting sentencepiece (from mediapipe)
#   Using cached sentencepiece-0.2.0-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting ml_dtypes>=0.5.0 (from jax->mediapipe)
#   Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting opt_einsum (from jax->mediapipe)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting scipy>=1.11.1 (from jax->mediapipe)
#   Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapipe)
#   Using cached fonttools-4.58.0-cp312-cp312-win_amd64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (25.0)
# Collecting pillow>=8 (from matplotlib->mediapipe)
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapipe)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl (51.0 MB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached protobuf-4.25.7-cp310-abi3-win_amd64.whl (413 kB)
# Using cached sounddevice-0.5.2-py3-none-win_amd64.whl (363 kB)
# Using cached absl_py-2.2.2-py3-none-any.whl (135 kB)
# Using cached jax-0.6.0-py3-none-any.whl (2.3 MB)
# Using cached jaxlib-0.6.0-cp312-cp312-win_amd64.whl (56.4 MB)
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/46.2 MB 5.6 MB/s eta 0:00:09
#    - -------------------------------------- 1.6/46.2 MB 5.6 MB/s eta 0:00:08
#    -- ------------------------------------- 2.9/46.2 MB 5.8 MB/s eta 0:00:08
#    --- ------------------------------------ 4.2/46.2 MB 5.9 MB/s eta 0:00:08
#    ---- ----------------------------------- 5.2/46.2 MB 5.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.0/46.2 MB 5.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.3/46.2 MB 5.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.8/46.2 MB 4.4 MB/s eta 0:00:09
#    ------ --------------------------------- 7.9/46.2 MB 4.5 MB/s eta 0:00:09
#    ------- -------------------------------- 8.9/46.2 MB 4.6 MB/s eta 0:00:09
#    -------- ------------------------------- 9.7/46.2 MB 4.6 MB/s eta 0:00:08
#    --------- ------------------------------ 10.7/46.2 MB 4.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 12.1/46.2 MB 4.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 13.4/46.2 MB 4.8 MB/s eta 0:00:07
#    ------------ --------------------------- 14.7/46.2 MB 4.9 MB/s eta 0:00:07
#    ------------- -------------------------- 16.0/46.2 MB 5.0 MB/s eta 0:00:06
#    -------------- ------------------------- 17.3/46.2 MB 5.1 MB/s eta 0:00:06
#    --------------- ------------------------ 18.4/46.2 MB 5.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 19.7/46.2 MB 5.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 20.7/46.2 MB 5.2 MB/s eta 0:00:05
#    ------------------- -------------------- 22.0/46.2 MB 5.2 MB/s eta 0:00:05
#    ------------------- -------------------- 23.1/46.2 MB 5.3 MB/s eta 0:00:05
#    -------------------- ------------------- 23.9/46.2 MB 5.2 MB/s eta 0:00:05
#    --------------------- ------------------ 24.6/46.2 MB 5.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 26.0/46.2 MB 5.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 27.0/46.2 MB 5.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 27.5/46.2 MB 5.1 MB/s eta 0:00:04
#    ------------------------ --------------- 28.8/46.2 MB 5.1 MB/s eta 0:00:04
#    ------------------------- -------------- 29.6/46.2 MB 5.1 MB/s eta 0:00:04
#    -------------------------- ------------- 30.9/46.2 MB 5.1 MB/s eta 0:00:03
#    --------------------------- ------------ 32.0/46.2 MB 5.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 33.3/46.2 MB 5.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 34.3/46.2 MB 5.2 MB/s eta 0:00:03
#    ------------------------------ --------- 35.7/46.2 MB 5.2 MB/s eta 0:00:03
#    ------------------------------- -------- 36.7/46.2 MB 5.2 MB/s eta 0:00:02
#    -------------------------------- ------- 38.0/46.2 MB 5.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.3/46.2 MB 5.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.6/46.2 MB 5.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.9/46.2 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 43.0/46.2 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.6/46.2 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  45.9/46.2 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 5.4 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/992.0 kB ? eta -:--:--
#    ---------------------------------------- 992.0/992.0 kB 6.7 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl (210 kB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 3.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 5.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.0 MB 4.6 MB/s eta 0:00:09
#    -- ------------------------------------- 2.1/41.0 MB 5.3 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/41.0 MB 5.3 MB/s eta 0:00:08
#    --- ------------------------------------ 3.9/41.0 MB 4.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 5.0/41.0 MB 4.9 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.0/41.0 MB 4.8 MB/s eta 0:00:08
#    ------ --------------------------------- 6.8/41.0 MB 4.8 MB/s eta 0:00:08
#    ------- -------------------------------- 8.1/41.0 MB 4.9 MB/s eta 0:00:07
#    --------- ------------------------------ 9.4/41.0 MB 5.1 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.5/41.0 MB 5.1 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.8/41.0 MB 5.2 MB/s eta 0:00:06
#    ------------ --------------------------- 12.6/41.0 MB 5.2 MB/s eta 0:00:06
#    ------------- -------------------------- 13.4/41.0 MB 5.1 MB/s eta 0:00:06
#    -------------- ------------------------- 14.7/41.0 MB 5.1 MB/s eta 0:00:06
#    --------------- ------------------------ 15.7/41.0 MB 5.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.8/41.0 MB 5.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 17.8/41.0 MB 5.2 MB/s eta 0:00:05
#    ------------------ --------------------- 19.4/41.0 MB 5.3 MB/s eta 0:00:05
#    -------------------- ------------------- 20.7/41.0 MB 5.3 MB/s eta 0:00:04
#    --------------------- ------------------ 22.0/41.0 MB 5.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 23.3/41.0 MB 5.4 MB/s eta 0:00:04
#    ------------------------ --------------- 24.6/41.0 MB 5.5 MB/s eta 0:00:03
#    ------------------------- -------------- 25.7/41.0 MB 5.5 MB/s eta 0:00:03
#    -------------------------- ------------- 27.0/41.0 MB 5.5 MB/s eta 0:00:03
#    -------------------------- ------------- 27.5/41.0 MB 5.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 28.8/41.0 MB 5.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.1/41.0 MB 5.5 MB/s eta 0:00:02
#    ------------------------------ --------- 31.5/41.0 MB 5.5 MB/s eta 0:00:02
#    ------------------------------- -------- 32.8/41.0 MB 5.5 MB/s eta 0:00:02
#    --------------------------------- ------ 33.8/41.0 MB 5.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 5.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.2/41.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 37.2/41.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 38.5/41.0 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 39.8/41.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 5.5 MB/s eta 0:00:00
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: sentencepiece, flatbuffers, pyparsing, pycparser, protobuf, pillow, opt_einsum, numpy, kiwisolver, fonttools, cycler, attrs, absl-py, scipy, opencv-contrib-python, ml_dtypes, contourpy, CFFI, sounddevice, matplotlib, jaxlib, jax, mediapipe
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed CFFI-1.17.1 absl-py-2.2.2 attrs-25.3.0 contourpy-1.3.2 cycler-0.12.1 flatbuffers-25.2.10 fonttools-4.58.0 jax-0.6.0 jaxlib-0.6.0 kiwisolver-1.4.8 matplotlib-3.10.3 mediapipe-0.10.21 ml_dtypes-0.5.1 numpy-1.26.4 opencv-contrib-python-4.11.0.86 opt_einsum-3.4.0 pillow-11.2.1 protobuf-4.25.7 pycparser-2.22 pyparsing-3.2.3 scipy-1.15.3 sentencepiece-0.2.0 sounddevice-0.5.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import mediapipe as mp
import numpy as np


cap = cv2.VideoCapture(0)


background_img = cv2.imread(r"everest.jpg")


mp_selfie_segmentation = mp.solutions.selfie_segmentation
segmentor = mp_selfie_segmentation.SelfieSegmentation(model_selection=1)

while True:
    ret, frame = cap.read()
    if not ret:
        break

   
    frame = cv2.flip(frame, 1)

 
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

  
    results = segmentor.process(rgb_frame)
    mask = results.segmentation_mask


    condition = mask > 0.6

    
    bg_resized = cv2.resize(background_img, (frame.shape[1], frame.shape[0]))

   
    output = np.where(condition[..., None], frame, bg_resized)

   
    cv2.imshow("Virtual Background", output)

   
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
